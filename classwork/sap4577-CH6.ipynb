# %%
import numpy as np
import time

def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations

def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = x.copy()
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
         #Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations

# %%
#challenge 6a
A = np.array([[10, -1, 2, 0, 0], 
              [-1, 11, -1, 3, 0],
              [2, -1, 10, -1, 0], 
              [0, 3, -1, 8, -2], 
              [0, 0, 0, -2, 9],], dtype=float)
b = np.array([14, 22, 33, 26, 22], dtype=float)
tol = 1e-6
max_iterations = 100
x0 = np.zeros_like(b, dtype=float)
startg = time.perf_counter()
solution_g, iterations_g = gauss_seidel(A, b, x0, tol, max_iterations)
endg = time.perf_counter()
startj = time.perf_counter()
solution_j, iterations_j = jacobi(A, b, x0, tol, max_iterations)
endj=time.perf_counter()
print("gauss seidel: ", str(iterations_g), " tries")
print("time: ", str(endg-startg))
print(solution_g)
print("jacobi: ", str(iterations_j), " tries")
print("time: ", str(endj-startj))
print(solution_j)
# Out:
# gauss seidel:  9  tries
# time:  0.0006677079945802689
# [0.79456702 1.29952731 3.67692918 4.05889888 3.34642197]
# jacobi:  18  tries
# time:  0.0011426890268921852
# [0.79456684 1.29952743 3.67692912 4.05889899 3.34642183]

# %% [markdown]
# Challenge 6a^
#
# jacobi took double the iterations to converge and almost twice as long.

# %%
#challenge 6b
A = np.array([[1, 2, 3, 0, 0], 
              [2, 1, 2, 3, 0],
              [3, 2, 1, 2, 3], 
              [0, 3, 2, 1, 2], 
              [0, 0, 3, 2, 1],], dtype=float)
b = np.array([14, 22, 33, 26, 22], dtype=float)
tol = 1e-6
max_iterations = 100
x0 = np.zeros_like(b, dtype=float)
startg = time.perf_counter()
solution_g, iterations_g = gauss_seidel(A, b, x0, tol, max_iterations)
endg = time.perf_counter()
startj = time.perf_counter()
solution_j, iterations_j = jacobi(A, b, x0, tol, max_iterations)
endj=time.perf_counter()
print("gauss seidel: ", str(iterations_g), " tries")
print("time: ", str(endg-startg))
print(solution_g)
print("jacobi: ", str(iterations_j), " tries")
print("time: ", str(endj-startj))
print(solution_j)
# Out:
# gauss seidel:  100  tries
# time:  0.0053645719308406115
# [-8.70303388e+112  3.37515847e+113 -5.07312279e+113 -1.50300774e+113
#   1.82253839e+114]
# jacobi:  100  tries
# time:  0.0055061879102140665
# [-3.43010894e+85 -4.24934579e+85 -5.28966155e+85 -4.24934579e+85
#  -3.43010894e+85]

# %% [markdown]
# Challenge 6b^
#
# both did not converge. I tried higher max iterations but it produces a run time error for taking too long to run. This is because this is not a diagonal dominant matrix so this iterative process does not provide a good estimation.
