# %%
x = 2025
dec = x
b_back = ""
b_for = ""
while x>0: 
    b_back += str(x % 2)
    x = int(x / 2)
    
for i in range(len(b_back)):
   b_for += b_back[len(b_back)-i-1]

print("Decimal: ", str(dec))
print("Binary: ", b_back)
# Out:
# Decimal:  2025
# Binary:  10010111111
