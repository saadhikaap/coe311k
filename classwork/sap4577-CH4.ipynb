# %%
import numpy as np

# %%
c = 0
sum = 0
true = np.pi
for n in range(5000):
    num = (-1)**n
    den = (2*n)+1
    sum = sum + num/den
    if n%100 == 0 and n!=0:
        rel = abs((true-sum)/true)
        print("relative error at ", str(n), "th try is ", str(rel))
# Out:
# relative error at  100 th try is  0.7492121235490313
# relative error at  200 th try is  0.7496040946311516
# relative error at  300 th try is  0.7497356237476186
# relative error at  400 th try is  0.7498015527485623
# relative error at  500 th try is  0.7498411628896482
# relative error at  600 th try is  0.7498675916531318
# relative error at  700 th try is  0.7498864801268742
# relative error at  800 th try is  0.7499006523838466
# relative error at  900 th try is  0.7499116787491237
# relative error at  1000 th try is  0.7499205020462624
# relative error at  1100 th try is  0.7499277225657273
# relative error at  1200 th try is  0.749933740667982
# relative error at  1300 th try is  0.7499388336204518
# relative error at  1400 th try is  0.7499431995279013
# relative error at  1500 th try is  0.749946983702388
# relative error at  1600 th try is  0.7499502951506657
# relative error at  1700 th try is  0.7499532172459318
# relative error at  1800 th try is  0.7499558148443018
# ...
