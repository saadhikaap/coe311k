# %% [markdown]
# hello world script

# %%
print("String")
# Out:
# String

# %%
myfile = open("test.dat", 'w')
myfile.write(str(6))
myfile.write("\nHello World")
myfile.close()

# %%
myfile = open("test.dat", 'r')
print(myfile.read())
myfile.close()
# Out:
# 6
# Hello World

# %%
import math
import random 

def approxpi(numS):
    c = 0
    for i in range(numS):
        x = random.uniform(-1,1)
        y = random.uniform(-1,1)
        if (x**2 + y**2 < 1):
            c+=1
    pi = (4 * c)/numS
    return pi
        

print(approxpi(50))
print(approxpi(80))
print(approxpi(500))
# Out:
# 3.2
# 3.25
# 3.048

# %%
import matplotlib.plyplot as plt 
import numpy as np

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-3d59864e834d> in <module>
#       1 list1 = [1, 2]
# ----> 2 print(list1 + 2)
#
# TypeError: can only concatenate list (not "int") to list
